# %%
string = "sachin"
string.zfill(12)
# Out:
# '000000sachin'

# %%
string = "1234"
int(string.zfill(12))
# Out:
# 1234

# %%
text = "hello"
encoded = text.encode("utf-8")
print(encoded)  # b'hello'
# Out:
# b'hello'

# %%
text = "Hello {name}, you are {age} years old"
data = {"name": "Alice", "age": 30}

print(text.format_map(data))

# %%
email = "abhishek@gmail.com"

# %%
email.split("@")
# Out:
# ['abhishek', 'gmail.com']

# %%
after_split = email.split("@")

# %%
after_split
# Out:
# ['abhishek', 'gmail.com']

# %%
"@".join(after_split)
# Out:
# 'abhishek@gmail.com'

# %%
list1 = ["sachin","kumar","noida"]

# %%
" ".join(list1)
# Out:
# 'sachin kumar noida'

# %%
"_".join(list1)
# Out:
# 'sachin_kumar_noida'

# %%
string.center(50,"_")
# Out:
# '_______________________1234_______________________'

# %%
string.center(50,"@")
# Out:
# '@@@@@@@@@@@@@@@@@@@@@@@1234@@@@@@@@@@@@@@@@@@@@@@@'

# %%
with open(r"C:\Users\HP\Documents\my pass_file.txt") as file:
    password = file.read()

# %%
print(password)
# Out:
# 12345

# %%
password
# Out:
# '12345 \n\n'

# %%
file_password ='12345 \n\n'
my_password = '12345'

# %%
file_password.replace("\n","").strip()
# Out:
# '12345'

# %%
file_password.replace("\n","").replace(" ","")
# Out:
# '12345'

# %%
55==55
# Out:
# True

# %%
if 55==55:
    print("both value are equal")
# Out:
# both value are equal

# %%
if
